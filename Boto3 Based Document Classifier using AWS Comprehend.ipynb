# %% [markdown]
# ### Below exercise is meant for understanding how to integrate Python on a System with AWS Comprehend Services.
# #### Please note you need to have an AWS account for this and you need to complete the credentials and config settings on the system beforehand

# %% [markdown]
# #### We are going to do the below activities through this exercise:
#
# 1. Download the data & split it into train and test/truth dataset
# 2. Upload the data on AWS S3 by creating a bucket by calling S3 API
# 3. Build and train a classifier model using AWS Comprehend Services by calling Comprehend API
# 4. Once the model is build and trained, expose it to the test dataset from S3 bucket
# 5. Evaluate the model for accuracy, precision, recall, f1 score, etc

# %% [markdown]
# ### Importing the Libraries

# %%
import numpy as np
import pandas as pd
import os
import boto3
import json
import tarfile
import warnings
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Importing the data

# %%
# !wget http://mlg.ucd.ie/files/datasets/bbc-fulltext.zip

# %%
# !unzip bbc-fulltext.zip -d bbc

# %%
df = pd.DataFrame()
mapping = {}
source_path = "bbc/bbc/"

for i in sorted(os.listdir(source_path)):
    if os.path.isdir(source_path+i):
        mapping[i] = sorted(os.listdir(source_path+i))[:300]

label = []
data = []

for key, file in mapping.items():
    for fcontent in file:
        label.append(key)
        data.append(str(open(source_path+i+"/"+fcontent, encoding="cp1252").read().replace("\n"," "))[:5000])
        
df["document"] = data
df["label"] = label

#df = df.sample(frac=1).reset_index(drop=True)

df.to_csv("dataset.csv", header=False, index=False)

# %% [markdown]
# ### Creating Train & Test Datasets

# %%
X, y = df['document'], df['label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=0,stratify=y)

# %%
print('Xtrain Shape', X_train.shape)
print('Xtest Shape', X_test.shape)
print('y train Shape', y_train.shape)
print('y test Shape', y_test.shape)
# Out:
# Xtrain Shape (1050,)
# Xtest Shape (450,)
# y train Shape (1050,)
# y test Shape (450,)

# %% [markdown]
# ### Creating Train, Test & Truth Files for Uploading to S3

# %%
df_train = pd.DataFrame()
df_train['label'] = y_train
df_train['document'] = X_train

df_test = pd.DataFrame()
df_test['document'] = X_test

df_truth = pd.DataFrame()
df_truth['label'] = y_test
df_truth['document'] = X_test

df_train.to_csv('train.csv',index=False, header=False)
df_test.to_csv('test.csv',index=False, header=False)
df_truth.to_csv('truth.csv',index=False, header=False)

# %% [markdown]
# ### Creating a new S3 Bucket

# %%
s3_client = boto3.client('s3')
comprehend_client = boto3.client('comprehend')

# %%
response = s3_client.create_bucket(Bucket='doc-classifier-radwani',
                               ACL='private',
                               CreateBucketConfiguration={'LocationConstraint': 'ap-south-1'})
response
# Out:
# {'ResponseMetadata': {'RequestId': '8C2E661B9F978BE5',
#   'HostId': '55imwuXai0y7PtK/PbKg4Ggy9NlAvbcfX47KNc26qBne3PJdmX/a72fCVn/AsgREWguIjZEwT8I=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': '55imwuXai0y7PtK/PbKg4Ggy9NlAvbcfX47KNc26qBne3PJdmX/a72fCVn/AsgREWguIjZEwT8I=',
#    'x-amz-request-id': '8C2E661B9F978BE5',
#    'date': 'Tue, 24 Nov 2020 11:45:28 GMT',
#    'location': 'http://doc-classifier-radwani.s3.amazonaws.com/',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Location': 'http://doc-classifier-radwani.s3.amazonaws.com/'}

# %% [markdown]
# ### Uploading data on AWS S3

# %%
s3_client.upload_file(Filename="train.csv",Bucket="doc-classifier-radwani",Key="train.csv")
s3_client.upload_file(Filename="test.csv",Bucket="doc-classifier-radwani",Key="test.csv")
s3_client.upload_file(Filename="truth.csv",Bucket="doc-classifier-radwani",Key="truth.csv")

# %% [markdown]
# ### Creating a Custom Classifier & Training it

# %%
# Create a document classifier
create_response = comprehend_client.create_document_classifier(
    InputDataConfig={
        'S3Uri': 's3://doc-classifier-radwani/train.csv'
    },
    DataAccessRoleArn='arn:aws:iam::341732173095:role/service-role/AmazonComprehendServiceRole-doc-classifier-rad-role-2',
    DocumentClassifierName='doc-classifier-by-radwani',
    LanguageCode='en'
)
print("Create response:\n")
create_response
# Out:
# Create response:
# {'DocumentClassifierArn': 'arn:aws:comprehend:ap-south-1:341732173095:document-classifier/doc-classifier-by-radwani',
#  'ResponseMetadata': {'RequestId': 'ec597c89-5ab9-4f7c-9b7e-8f2da7f5e2a8',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'ec597c89-5ab9-4f7c-9b7e-8f2da7f5e2a8',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '116',
#    'date': 'Tue, 24 Nov 2020 15:30:52 GMT'},
#   'RetryAttempts': 0}}

# %%
# Check the status of the classifier
describe_response = comprehend_client.describe_document_classifier(DocumentClassifierArn=create_response['DocumentClassifierArn'])
print("Status of Classifier:\n")
describe_response['DocumentClassifierProperties']['Status']
# Out:
# Status of Classifier:
# 'TRAINED'

# %% [markdown]
# ### Creating a custom job and using classifier on test dataset

# %%
start_response = comprehend_client.start_document_classification_job(
    InputDataConfig={
        'S3Uri': 's3://doc-classifier-radwani/test.csv',
        'InputFormat': 'ONE_DOC_PER_LINE'
    },
    OutputDataConfig={
        'S3Uri': 's3://doc-classifier-radwani/'
    },
    DataAccessRoleArn='arn:aws:iam::341732173095:role/service-role/AmazonComprehendServiceRole-doc-classifier-rad-role-2',
    DocumentClassifierArn=
    'arn:aws:comprehend:ap-south-1:341732173095:document-classifier/doc-classifier-by-radwani'
)

print("Start response:\n")
start_response
# Out:
# Start response:
# {'JobId': '679c821820e5036c986eecfb0ba943eb',
#  'JobStatus': 'SUBMITTED',
#  'ResponseMetadata': {'RequestId': 'f1b2c08b-15ab-4cde-b3db-f5d5f2390c3a',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'f1b2c08b-15ab-4cde-b3db-f5d5f2390c3a',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '68',
#    'date': 'Tue, 24 Nov 2020 16:22:54 GMT'},
#   'RetryAttempts': 0}}

# %%
# Check the status of the job
describe_response = comprehend_client.describe_document_classification_job(JobId=start_response['JobId'])
print("Job Status:\n")
describe_response['DocumentClassificationJobProperties']['JobStatus']
# Out:
# Job Status:
# 'COMPLETED'

# %% [markdown]
# ### Checking the test output against truth dataset

# %% [markdown]
# #### Get the output file

# %%
s3_client.download_file(Bucket='doc-classifier-radwani', Key='341732173095-CLN-679c821820e5036c986eecfb0ba943eb/output/output.tar.gz', Filename='output.tar.gz')

# %%
my_tar = tarfile.open('output.tar.gz')
my_tar.extractall('./outputfiles') # specify which folder to extract to
my_tar.close()

# %%
with open('outputfiles/predictions.jsonl', 'r') as file:
    file = file.readlines()

# %%
from pprint import pprint

# %%
for line in file:
    pprint(json.loads(line))
# Out:
# {'Classes': [{'Name': 'business', 'Score': 0.2168},
#              {'Name': 'entertainment', 'Score': 0.2139},
#              {'Name': 'politics', 'Score': 0.1998}],
#  'File': 'test.csv',
#  'Line': '0'}
# {'Classes': [{'Name': 'business', 'Score': 0.2166},
#              {'Name': 'entertainment', 'Score': 0.213},
#              {'Name': 'politics', 'Score': 0.2026}],
#  'File': 'test.csv',
#  'Line': '1'}
# {'Classes': [{'Name': 'business', 'Score': 0.2156},
#              {'Name': 'entertainment', 'Score': 0.2149},
#              {'Name': 'politics', 'Score': 0.2019}],
#  'File': 'test.csv',
#  'Line': '2'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2151},
#              {'Name': 'business', 'Score': 0.2147},
#              {'Name': 'politics', 'Score': 0.2016}],
#  'File': 'test.csv',
#  'Line': '3'}
# {'Classes': [{'Name': 'business', 'Score': 0.2156},
#              {'Name': 'entertainment', 'Score': 0.2139},
#              {'Name': 'politics', 'Score': 0.2009}],
#  'File': 'test.csv',
#  'Line': '4'}
# {'Classes': [{'Name': 'business', 'Score': 0.2156},
#              {'Name': 'entertainment', 'Score': 0.2113},
#              {'Name': 'politics', 'Score': 0.2014}],
#  'File': 'test.csv',
#  'Line': '5'}
# {'Classes': [{'Name': 'business', 'Score': 0.2166},
#              {'Name': 'entertainment', 'Score': 0.2148},
#              {'Name': 'politics', 'Score': 0.2027}],
#  'File': 'test.csv',
#  'Line': '6'}
# {'Classes': [{'Name': 'business', 'Score': 0.212},
#              {'Name': 'entertainment', 'Score': 0.2117},
#              {'Name': 'politics', 'Score': 0.2061}],
#  'File': 'test.csv',
#  'Line': '7'}
# {'Classes': [{'Name': 'business', 'Score': 0.2128},
#              {'Name': 'entertainment', 'Score': 0.2103},
#              {'Name': 'politics', 'Score': 0.2064}],
#  'File': 'test.csv',
#  'Line': '8'}
# {'Classes': [{'Name': 'business', 'Score': 0.2169},
#              {'Name': 'entertainment', 'Score': 0.2154},
#              {'Name': 'politics', 'Score': 0.2008}],
#  'File': 'test.csv',
#  'Line': '9'}
# {'Classes': [{'Name': 'business', 'Score': 0.2153},
#              {'Name': 'entertainment', 'Score': 0.21},
#              {'Name': 'politics', 'Score': 0.2044}],
#  'File': 'test.csv',
#  'Line': '10'}
# {'Classes': [{'Name': 'business', 'Score': 0.2154},
#              {'Name': 'entertainment', 'Score': 0.2108},
#              {'Name': 'politics', 'Score': 0.2048}],
#  'File': 'test.csv',
#  'Line': '11'}
# {'Classes': [{'Name': 'business', 'Score': 0.2134},
#              {'Name': 'politics', 'Score': 0.2114},
#              {'Name': 'entertainment', 'Score': 0.2051}],
#  'File': 'test.csv',
#  'Line': '12'}
# {'Classes': [{'Name': 'business', 'Score': 0.2154},
#              {'Name': 'entertainment', 'Score': 0.2125},
#              {'Name': 'politics', 'Score': 0.2025}],
#  'File': 'test.csv',
#  'Line': '13'}
# {'Classes': [{'Name': 'business', 'Score': 0.2153},
#              {'Name': 'entertainment', 'Score': 0.2127},
#              {'Name': 'politics', 'Score': 0.2025}],
#  'File': 'test.csv',
#  'Line': '14'}
# {'Classes': [{'Name': 'business', 'Score': 0.2145},
#              {'Name': 'entertainment', 'Score': 0.2121},
#              {'Name': 'politics', 'Score': 0.2026}],
#  'File': 'test.csv',
#  'Line': '15'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2172},
#              {'Name': 'business', 'Score': 0.2164},
#              {'Name': 'sport', 'Score': 0.1989}],
#  'File': 'test.csv',
#  'Line': '16'}
# {'Classes': [{'Name': 'business', 'Score': 0.2165},
#              {'Name': 'entertainment', 'Score': 0.2096},
#              {'Name': 'politics', 'Score': 0.2041}],
#  'File': 'test.csv',
#  'Line': '17'}
# {'Classes': [{'Name': 'business', 'Score': 0.2151},
#              {'Name': 'entertainment', 'Score': 0.2148},
#              {'Name': 'politics', 'Score': 0.2012}],
#  'File': 'test.csv',
#  'Line': '18'}
# {'Classes': [{'Name': 'business', 'Score': 0.2149},
#              {'Name': 'entertainment', 'Score': 0.2134},
#              {'Name': 'politics', 'Score': 0.2022}],
#  'File': 'test.csv',
#  'Line': '19'}
# {'Classes': [{'Name': 'business', 'Score': 0.216},
#              {'Name': 'entertainment', 'Score': 0.2134},
#              {'Name': 'politics', 'Score': 0.2028}],
#  'File': 'test.csv',
#  'Line': '20'}
# {'Classes': [{'Name': 'business', 'Score': 0.215},
#              {'Name': 'entertainment', 'Score': 0.2102},
#              {'Name': 'politics', 'Score': 0.205}],
#  'File': 'test.csv',
#  'Line': '21'}
# {'Classes': [{'Name': 'business', 'Score': 0.2164},
#              {'Name': 'entertainment', 'Score': 0.2131},
#              {'Name': 'politics', 'Score': 0.2014}],
#  'File': 'test.csv',
#  'Line': '22'}
# {'Classes': [{'Name': 'business', 'Score': 0.2169},
#              {'Name': 'entertainment', 'Score': 0.2154},
#              {'Name': 'politics', 'Score': 0.2008}],
#  'File': 'test.csv',
#  'Line': '23'}
# {'Classes': [{'Name': 'business', 'Score': 0.2155},
#              {'Name': 'entertainment', 'Score': 0.2145},
#              {'Name': 'politics', 'Score': 0.2016}],
#  'File': 'test.csv',
#  'Line': '24'}
# {'Classes': [{'Name': 'business', 'Score': 0.212},
#              {'Name': 'entertainment', 'Score': 0.2114},
#              {'Name': 'politics', 'Score': 0.2069}],
#  'File': 'test.csv',
#  'Line': '25'}
# {'Classes': [{'Name': 'business', 'Score': 0.2175},
#              {'Name': 'entertainment', 'Score': 0.2116},
#              {'Name': 'politics', 'Score': 0.2031}],
#  'File': 'test.csv',
#  'Line': '26'}
# {'Classes': [{'Name': 'business', 'Score': 0.2129},
#              {'Name': 'entertainment', 'Score': 0.2125},
#              {'Name': 'politics', 'Score': 0.2037}],
#  'File': 'test.csv',
#  'Line': '27'}
# {'Classes': [{'Name': 'business', 'Score': 0.2148},
#              {'Name': 'entertainment', 'Score': 0.2104},
#              {'Name': 'politics', 'Score': 0.2068}],
#  'File': 'test.csv',
#  'Line': '28'}
# {'Classes': [{'Name': 'business', 'Score': 0.215},
#              {'Name': 'entertainment', 'Score': 0.2125},
#              {'Name': 'politics', 'Score': 0.2024}],
#  'File': 'test.csv',
#  'Line': '29'}
# {'Classes': [{'Name': 'business', 'Score': 0.2118},
#              {'Name': 'entertainment', 'Score': 0.2102},
#              {'Name': 'politics', 'Score': 0.2051}],
#  'File': 'test.csv',
#  'Line': '30'}
# {'Classes': [{'Name': 'business', 'Score': 0.2152},
#              {'Name': 'entertainment', 'Score': 0.2145},
#              {'Name': 'politics', 'Score': 0.2017}],
#  'File': 'test.csv',
#  'Line': '31'}
# {'Classes': [{'Name': 'business', 'Score': 0.2147},
#              {'Name': 'entertainment', 'Score': 0.2116},
#              {'Name': 'politics', 'Score': 0.2037}],
#  'File': 'test.csv',
#  'Line': '32'}
# {'Classes': [{'Name': 'business', 'Score': 0.2163},
#              {'Name': 'entertainment', 'Score': 0.2106},
#              {'Name': 'politics', 'Score': 0.2044}],
#  'File': 'test.csv',
#  'Line': '33'}
# {'Classes': [{'Name': 'business', 'Score': 0.2157},
#              {'Name': 'entertainment', 'Score': 0.2115},
#              {'Name': 'politics', 'Score': 0.2025}],
#  'File': 'test.csv',
#  'Line': '34'}
# {'Classes': [{'Name': 'business', 'Score': 0.2134},
#              {'Name': 'entertainment', 'Score': 0.2111},
#              {'Name': 'politics', 'Score': 0.2073}],
#  'File': 'test.csv',
#  'Line': '35'}
# {'Classes': [{'Name': 'business', 'Score': 0.2149},
#              {'Name': 'entertainment', 'Score': 0.2144},
#              {'Name': 'politics', 'Score': 0.2018}],
#  'File': 'test.csv',
#  'Line': '36'}
# {'Classes': [{'Name': 'business', 'Score': 0.2138},
#              {'Name': 'entertainment', 'Score': 0.2114},
#              {'Name': 'politics', 'Score': 0.2057}],
#  'File': 'test.csv',
#  'Line': '37'}
# {'Classes': [{'Name': 'business', 'Score': 0.2162},
#              {'Name': 'entertainment', 'Score': 0.2146},
#              {'Name': 'politics', 'Score': 0.2}],
#  'File': 'test.csv',
#  'Line': '38'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2147},
#              {'Name': 'business', 'Score': 0.2138},
#              {'Name': 'politics', 'Score': 0.203}],
#  'File': 'test.csv',
#  'Line': '39'}
# {'Classes': [{'Name': 'business', 'Score': 0.2148},
#              {'Name': 'entertainment', 'Score': 0.2104},
#              {'Name': 'politics', 'Score': 0.2068}],
#  'File': 'test.csv',
#  'Line': '40'}
# {'Classes': [{'Name': 'business', 'Score': 0.2149},
#              {'Name': 'entertainment', 'Score': 0.2096},
#              {'Name': 'politics', 'Score': 0.2063}],
#  'File': 'test.csv',
#  'Line': '41'}
# {'Classes': [{'Name': 'business', 'Score': 0.2156},
#              {'Name': 'entertainment', 'Score': 0.2139},
#              {'Name': 'politics', 'Score': 0.2009}],
#  'File': 'test.csv',
#  'Line': '42'}
# {'Classes': [{'Name': 'business', 'Score': 0.2155},
#              {'Name': 'entertainment', 'Score': 0.2145},
#              {'Name': 'politics', 'Score': 0.2008}],
#  'File': 'test.csv',
#  'Line': '43'}
# {'Classes': [{'Name': 'business', 'Score': 0.2138},
#              {'Name': 'entertainment', 'Score': 0.2134},
#              {'Name': 'politics', 'Score': 0.2033}],
#  'File': 'test.csv',
#  'Line': '44'}
# {'Classes': [{'Name': 'business', 'Score': 0.2128},
#              {'Name': 'entertainment', 'Score': 0.2089},
#              {'Name': 'politics', 'Score': 0.2086}],
#  'File': 'test.csv',
#  'Line': '45'}
# {'Classes': [{'Name': 'business', 'Score': 0.2189},
#              {'Name': 'entertainment', 'Score': 0.2158},
#              {'Name': 'politics', 'Score': 0.198}],
#  'File': 'test.csv',
#  'Line': '46'}
# {'Classes': [{'Name': 'business', 'Score': 0.2157},
#              {'Name': 'entertainment', 'Score': 0.2099},
#              {'Name': 'politics', 'Score': 0.2052}],
#  'File': 'test.csv',
#  'Line': '47'}
# {'Classes': [{'Name': 'business', 'Score': 0.2128},
#              {'Name': 'entertainment', 'Score': 0.2103},
#              {'Name': 'politics', 'Score': 0.2064}],
#  'File': 'test.csv',
#  'Line': '48'}
# {'Classes': [{'Name': 'business', 'Score': 0.2143},
#              {'Name': 'entertainment', 'Score': 0.2107},
#              {'Name': 'politics', 'Score': 0.2026}],
#  'File': 'test.csv',
#  'Line': '49'}
# {'Classes': [{'Name': 'business', 'Score': 0.2161},
#              {'Name': 'entertainment', 'Score': 0.2127},
#              {'Name': 'politics', 'Score': 0.2013}],
#  'File': 'test.csv',
#  'Line': '50'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2152},
#              {'Name': 'business', 'Score': 0.2131},
#              {'Name': 'politics', 'Score': 0.2022}],
#  'File': 'test.csv',
#  'Line': '51'}
# {'Classes': [{'Name': 'business', 'Score': 0.2162},
#              {'Name': 'entertainment', 'Score': 0.2128},
#              {'Name': 'politics', 'Score': 0.2014}],
#  'File': 'test.csv',
#  'Line': '52'}
# {'Classes': [{'Name': 'business', 'Score': 0.2137},
#              {'Name': 'entertainment', 'Score': 0.2122},
#              {'Name': 'politics', 'Score': 0.2044}],
#  'File': 'test.csv',
#  'Line': '53'}
# {'Classes': [{'Name': 'business', 'Score': 0.2148},
#              {'Name': 'entertainment', 'Score': 0.2104},
#              {'Name': 'politics', 'Score': 0.2068}],
#  'File': 'test.csv',
#  'Line': '54'}
# {'Classes': [{'Name': 'business', 'Score': 0.2163},
#              {'Name': 'entertainment', 'Score': 0.2127},
#              {'Name': 'politics', 'Score': 0.2025}],
#  'File': 'test.csv',
#  'Line': '55'}
# {'Classes': [{'Name': 'business', 'Score': 0.2128},
#              {'Name': 'entertainment', 'Score': 0.2103},
#              {'Name': 'politics', 'Score': 0.2064}],
#  'File': 'test.csv',
#  'Line': '56'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.216},
#              {'Name': 'business', 'Score': 0.2132},
#              {'Name': 'politics', 'Score': 0.2004}],
#  'File': 'test.csv',
#  'Line': '57'}
# {'Classes': [{'Name': 'business', 'Score': 0.216},
#              {'Name': 'entertainment', 'Score': 0.2123},
#              {'Name': 'politics', 'Score': 0.2008}],
#  'File': 'test.csv',
#  'Line': '58'}
# {'Classes': [{'Name': 'business', 'Score': 0.215},
#              {'Name': 'entertainment', 'Score': 0.2142},
#              {'Name': 'politics', 'Score': 0.2002}],
#  'File': 'test.csv',
#  'Line': '59'}
# {'Classes': [{'Name': 'business', 'Score': 0.2146},
#              {'Name': 'entertainment', 'Score': 0.2131},
#              {'Name': 'politics', 'Score': 0.203}],
#  'File': 'test.csv',
#  'Line': '60'}
# {'Classes': [{'Name': 'business', 'Score': 0.2135},
#              {'Name': 'entertainment', 'Score': 0.2124},
#              {'Name': 'politics', 'Score': 0.2068}],
#  'File': 'test.csv',
#  'Line': '61'}
# {'Classes': [{'Name': 'business', 'Score': 0.2149},
#              {'Name': 'entertainment', 'Score': 0.2137},
#              {'Name': 'politics', 'Score': 0.2009}],
#  'File': 'test.csv',
#  'Line': '62'}
# {'Classes': [{'Name': 'business', 'Score': 0.2158},
#              {'Name': 'entertainment', 'Score': 0.2111},
#              {'Name': 'politics', 'Score': 0.2009}],
#  'File': 'test.csv',
#  'Line': '63'}
# {'Classes': [{'Name': 'business', 'Score': 0.216},
#              {'Name': 'entertainment', 'Score': 0.2123},
#              {'Name': 'politics', 'Score': 0.2044}],
#  'File': 'test.csv',
#  'Line': '64'}
# {'Classes': [{'Name': 'business', 'Score': 0.2124},
#              {'Name': 'entertainment', 'Score': 0.2114},
#              {'Name': 'politics', 'Score': 0.2049}],
#  'File': 'test.csv',
#  'Line': '65'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2164},
#              {'Name': 'business', 'Score': 0.2163},
#              {'Name': 'politics', 'Score': 0.2005}],
#  'File': 'test.csv',
#  'Line': '66'}
# {'Classes': [{'Name': 'business', 'Score': 0.2158},
#              {'Name': 'entertainment', 'Score': 0.214},
#              {'Name': 'politics', 'Score': 0.1999}],
#  'File': 'test.csv',
#  'Line': '67'}
# {'Classes': [{'Name': 'business', 'Score': 0.214},
#              {'Name': 'entertainment', 'Score': 0.2125},
#              {'Name': 'politics', 'Score': 0.2052}],
#  'File': 'test.csv',
#  'Line': '68'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2128},
#              {'Name': 'business', 'Score': 0.2124},
#              {'Name': 'politics', 'Score': 0.2049}],
#  'File': 'test.csv',
#  'Line': '69'}
# {'Classes': [{'Name': 'business', 'Score': 0.2132},
#              {'Name': 'entertainment', 'Score': 0.211},
#              {'Name': 'politics', 'Score': 0.2052}],
#  'File': 'test.csv',
#  'Line': '70'}
# {'Classes': [{'Name': 'business', 'Score': 0.215},
#              {'Name': 'entertainment', 'Score': 0.2118},
#              {'Name': 'politics', 'Score': 0.2047}],
#  'File': 'test.csv',
#  'Line': '71'}
# {'Classes': [{'Name': 'business', 'Score': 0.2143},
#              {'Name': 'entertainment', 'Score': 0.2113},
#              {'Name': 'politics', 'Score': 0.2046}],
#  'File': 'test.csv',
#  'Line': '72'}
# {'Classes': [{'Name': 'business', 'Score': 0.2162},
#              {'Name': 'entertainment', 'Score': 0.2121},
#              {'Name': 'politics', 'Score': 0.2039}],
#  'File': 'test.csv',
#  'Line': '73'}
# {'Classes': [{'Name': 'business', 'Score': 0.2169},
#              {'Name': 'entertainment', 'Score': 0.2113},
#              {'Name': 'politics', 'Score': 0.2031}],
#  'File': 'test.csv',
#  'Line': '74'}
# {'Classes': [{'Name': 'business', 'Score': 0.2157},
#              {'Name': 'entertainment', 'Score': 0.2124},
#              {'Name': 'politics', 'Score': 0.2008}],
#  'File': 'test.csv',
#  'Line': '75'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2178},
#              {'Name': 'business', 'Score': 0.2161},
#              {'Name': 'politics', 'Score': 0.1974}],
#  'File': 'test.csv',
#  'Line': '76'}
# {'Classes': [{'Name': 'business', 'Score': 0.2155},
#              {'Name': 'entertainment', 'Score': 0.2145},
#              {'Name': 'politics', 'Score': 0.2008}],
#  'File': 'test.csv',
#  'Line': '77'}
# {'Classes': [{'Name': 'business', 'Score': 0.2132},
#              {'Name': 'entertainment', 'Score': 0.2127},
#              {'Name': 'politics', 'Score': 0.2035}],
#  'File': 'test.csv',
#  'Line': '78'}
# {'Classes': [{'Name': 'business', 'Score': 0.2147},
#              {'Name': 'entertainment', 'Score': 0.2136},
#              {'Name': 'politics', 'Score': 0.2021}],
#  'File': 'test.csv',
#  'Line': '79'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2155},
#              {'Name': 'business', 'Score': 0.2148},
#              {'Name': 'politics', 'Score': 0.2012}],
#  'File': 'test.csv',
#  'Line': '80'}
# {'Classes': [{'Name': 'business', 'Score': 0.212},
#              {'Name': 'entertainment', 'Score': 0.2114},
#              {'Name': 'politics', 'Score': 0.2069}],
#  'File': 'test.csv',
#  'Line': '81'}
# {'Classes': [{'Name': 'business', 'Score': 0.2141},
#              {'Name': 'entertainment', 'Score': 0.211},
#              {'Name': 'politics', 'Score': 0.2059}],
#  'File': 'test.csv',
#  'Line': '82'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2135},
#              {'Name': 'business', 'Score': 0.2131},
#              {'Name': 'politics', 'Score': 0.2039}],
#  'File': 'test.csv',
#  'Line': '83'}
# {'Classes': [{'Name': 'business', 'Score': 0.2137},
#              {'Name': 'entertainment', 'Score': 0.2115},
#              {'Name': 'politics', 'Score': 0.2037}],
#  'File': 'test.csv',
#  'Line': '84'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2161},
#              {'Name': 'business', 'Score': 0.2118},
#              {'Name': 'sport', 'Score': 0.2002}],
#  'File': 'test.csv',
#  'Line': '85'}
# {'Classes': [{'Name': 'business', 'Score': 0.2161},
#              {'Name': 'entertainment', 'Score': 0.2122},
#              {'Name': 'politics', 'Score': 0.2041}],
#  'File': 'test.csv',
#  'Line': '86'}
# {'Classes': [{'Name': 'business', 'Score': 0.2147},
#              {'Name': 'entertainment', 'Score': 0.2124},
#              {'Name': 'politics', 'Score': 0.2018}],
#  'File': 'test.csv',
#  'Line': '87'}
# {'Classes': [{'Name': 'business', 'Score': 0.2121},
#              {'Name': 'entertainment', 'Score': 0.2106},
#              {'Name': 'politics', 'Score': 0.2057}],
#  'File': 'test.csv',
#  'Line': '88'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2147},
#              {'Name': 'business', 'Score': 0.2138},
#              {'Name': 'politics', 'Score': 0.203}],
#  'File': 'test.csv',
#  'Line': '89'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2122},
#              {'Name': 'business', 'Score': 0.2111},
#              {'Name': 'politics', 'Score': 0.2066}],
#  'File': 'test.csv',
#  'Line': '90'}
# {'Classes': [{'Name': 'business', 'Score': 0.2153},
#              {'Name': 'entertainment', 'Score': 0.2134},
#              {'Name': 'politics', 'Score': 0.201}],
#  'File': 'test.csv',
#  'Line': '91'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2138},
#              {'Name': 'business', 'Score': 0.2118},
#              {'Name': 'politics', 'Score': 0.2051}],
#  'File': 'test.csv',
#  'Line': '92'}
# {'Classes': [{'Name': 'business', 'Score': 0.2137},
#              {'Name': 'entertainment', 'Score': 0.2115},
#              {'Name': 'politics', 'Score': 0.2037}],
#  'File': 'test.csv',
#  'Line': '93'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2133},
#              {'Name': 'business', 'Score': 0.2132},
#              {'Name': 'politics', 'Score': 0.2031}],
#  'File': 'test.csv',
#  'Line': '94'}
# {'Classes': [{'Name': 'business', 'Score': 0.2149},
#              {'Name': 'entertainment', 'Score': 0.2126},
#              {'Name': 'politics', 'Score': 0.203}],
#  'File': 'test.csv',
#  'Line': '95'}
# {'Classes': [{'Name': 'business', 'Score': 0.214},
#              {'Name': 'entertainment', 'Score': 0.2125},
#              {'Name': 'politics', 'Score': 0.2052}],
#  'File': 'test.csv',
#  'Line': '96'}
# {'Classes': [{'Name': 'business', 'Score': 0.2122},
#              {'Name': 'entertainment', 'Score': 0.2086},
#              {'Name': 'politics', 'Score': 0.2077}],
#  'File': 'test.csv',
#  'Line': '97'}
# {'Classes': [{'Name': 'business', 'Score': 0.2132},
#              {'Name': 'entertainment', 'Score': 0.2091},
#              {'Name': 'politics', 'Score': 0.2063}],
#  'File': 'test.csv',
#  'Line': '98'}
# {'Classes': [{'Name': 'business', 'Score': 0.212},
#              {'Name': 'entertainment', 'Score': 0.2114},
#              {'Name': 'politics', 'Score': 0.2069}],
#  'File': 'test.csv',
#  'Line': '99'}
# {'Classes': [{'Name': 'business', 'Score': 0.2174},
#              {'Name': 'entertainment', 'Score': 0.2139},
#              {'Name': 'politics', 'Score': 0.2004}],
#  'File': 'test.csv',
#  'Line': '100'}
# {'Classes': [{'Name': 'business', 'Score': 0.2162},
#              {'Name': 'entertainment', 'Score': 0.2121},
#              {'Name': 'politics', 'Score': 0.2039}],
#  'File': 'test.csv',
#  'Line': '101'}
# {'Classes': [{'Name': 'business', 'Score': 0.2133},
#              {'Name': 'entertainment', 'Score': 0.2133},
#              {'Name': 'politics', 'Score': 0.2028}],
#  'File': 'test.csv',
#  'Line': '102'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2142},
#              {'Name': 'business', 'Score': 0.2133},
#              {'Name': 'politics', 'Score': 0.2041}],
#  'File': 'test.csv',
#  'Line': '103'}
# {'Classes': [{'Name': 'business', 'Score': 0.2151},
#              {'Name': 'entertainment', 'Score': 0.2148},
#              {'Name': 'politics', 'Score': 0.2012}],
#  'File': 'test.csv',
#  'Line': '104'}
# {'Classes': [{'Name': 'business', 'Score': 0.216},
#              {'Name': 'entertainment', 'Score': 0.2123},
#              {'Name': 'politics', 'Score': 0.205}],
#  'File': 'test.csv',
#  'Line': '105'}
# {'Classes': [{'Name': 'business', 'Score': 0.2163},
#              {'Name': 'entertainment', 'Score': 0.2153},
#              {'Name': 'politics', 'Score': 0.2008}],
#  'File': 'test.csv',
#  'Line': '106'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2144},
#              {'Name': 'business', 'Score': 0.2139},
#              {'Name': 'politics', 'Score': 0.2037}],
#  'File': 'test.csv',
#  'Line': '107'}
# {'Classes': [{'Name': 'business', 'Score': 0.2149},
#              {'Name': 'entertainment', 'Score': 0.2113},
#              {'Name': 'politics', 'Score': 0.2044}],
#  'File': 'test.csv',
#  'Line': '108'}
# {'Classes': [{'Name': 'business', 'Score': 0.2166},
#              {'Name': 'entertainment', 'Score': 0.2148},
#              {'Name': 'politics', 'Score': 0.2027}],
#  'File': 'test.csv',
#  'Line': '109'}
# {'Classes': [{'Name': 'business', 'Score': 0.2162},
#              {'Name': 'entertainment', 'Score': 0.2128},
#              {'Name': 'politics', 'Score': 0.2014}],
#  'File': 'test.csv',
#  'Line': '110'}
# {'Classes': [{'Name': 'business', 'Score': 0.2159},
#              {'Name': 'entertainment', 'Score': 0.2098},
#              {'Name': 'politics', 'Score': 0.2054}],
#  'File': 'test.csv',
#  'Line': '111'}
# {'Classes': [{'Name': 'business', 'Score': 0.2154},
#              {'Name': 'entertainment', 'Score': 0.2125},
#              {'Name': 'politics', 'Score': 0.2025}],
#  'File': 'test.csv',
#  'Line': '112'}
# {'Classes': [{'Name': 'business', 'Score': 0.2165},
#              {'Name': 'entertainment', 'Score': 0.2096},
#              {'Name': 'politics', 'Score': 0.2041}],
#  'File': 'test.csv',
#  'Line': '113'}
# {'Classes': [{'Name': 'business', 'Score': 0.2158},
#              {'Name': 'entertainment', 'Score': 0.214},
#              {'Name': 'politics', 'Score': 0.1999}],
#  'File': 'test.csv',
#  'Line': '114'}
# {'Classes': [{'Name': 'business', 'Score': 0.2137},
#              {'Name': 'entertainment', 'Score': 0.2127},
#              {'Name': 'politics', 'Score': 0.2043}],
#  'File': 'test.csv',
#  'Line': '115'}
# {'Classes': [{'Name': 'business', 'Score': 0.2188},
#              {'Name': 'entertainment', 'Score': 0.2151},
#              {'Name': 'politics', 'Score': 0.1983}],
#  'File': 'test.csv',
#  'Line': '116'}
# {'Classes': [{'Name': 'business', 'Score': 0.2128},
#              {'Name': 'entertainment', 'Score': 0.2103},
#              {'Name': 'politics', 'Score': 0.2064}],
#  'File': 'test.csv',
#  'Line': '117'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2147},
#              {'Name': 'business', 'Score': 0.2138},
#              {'Name': 'politics', 'Score': 0.203}],
#  'File': 'test.csv',
#  'Line': '118'}
# {'Classes': [{'Name': 'business', 'Score': 0.219},
#              {'Name': 'entertainment', 'Score': 0.2137},
#              {'Name': 'politics', 'Score': 0.1991}],
#  'File': 'test.csv',
#  'Line': '119'}
# {'Classes': [{'Name': 'business', 'Score': 0.2143},
#              {'Name': 'entertainment', 'Score': 0.2098},
#              {'Name': 'politics', 'Score': 0.2074}],
#  'File': 'test.csv',
#  'Line': '120'}
# {'Classes': [{'Name': 'business', 'Score': 0.2147},
#              {'Name': 'entertainment', 'Score': 0.2136},
#              {'Name': 'politics', 'Score': 0.2021}],
#  'File': 'test.csv',
#  'Line': '121'}
# {'Classes': [{'Name': 'business', 'Score': 0.2159},
#              {'Name': 'entertainment', 'Score': 0.2098},
#              {'Name': 'politics', 'Score': 0.2054}],
#  'File': 'test.csv',
#  'Line': '122'}
# {'Classes': [{'Name': 'business', 'Score': 0.2153},
#              {'Name': 'entertainment', 'Score': 0.213},
#              {'Name': 'politics', 'Score': 0.2029}],
#  'File': 'test.csv',
#  'Line': '123'}
# {'Classes': [{'Name': 'business', 'Score': 0.2127},
#              {'Name': 'entertainment', 'Score': 0.2114},
#              {'Name': 'politics', 'Score': 0.2058}],
#  'File': 'test.csv',
#  'Line': '124'}
# {'Classes': [{'Name': 'business', 'Score': 0.2126},
#              {'Name': 'entertainment', 'Score': 0.2086},
#              {'Name': 'politics', 'Score': 0.2082}],
#  'File': 'test.csv',
#  'Line': '125'}
# {'Classes': [{'Name': 'business', 'Score': 0.2144},
#              {'Name': 'entertainment', 'Score': 0.2123},
#              {'Name': 'politics', 'Score': 0.2037}],
#  'File': 'test.csv',
#  'Line': '126'}
# {'Classes': [{'Name': 'business', 'Score': 0.2126},
#              {'Name': 'entertainment', 'Score': 0.2123},
#              {'Name': 'politics', 'Score': 0.2034}],
#  'File': 'test.csv',
#  'Line': '127'}
# {'Classes': [{'Name': 'business', 'Score': 0.2161},
#              {'Name': 'entertainment', 'Score': 0.2127},
#              {'Name': 'politics', 'Score': 0.2013}],
#  'File': 'test.csv',
#  'Line': '128'}
# {'Classes': [{'Name': 'business', 'Score': 0.2148},
#              {'Name': 'entertainment', 'Score': 0.2104},
#              {'Name': 'politics', 'Score': 0.2068}],
#  'File': 'test.csv',
#  'Line': '129'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2139},
#              {'Name': 'business', 'Score': 0.2137},
#              {'Name': 'politics', 'Score': 0.2023}],
#  'File': 'test.csv',
#  'Line': '130'}
# {'Classes': [{'Name': 'business', 'Score': 0.2153},
#              {'Name': 'entertainment', 'Score': 0.21},
#              {'Name': 'politics', 'Score': 0.2044}],
#  'File': 'test.csv',
#  'Line': '131'}
# {'Classes': [{'Name': 'business', 'Score': 0.2152},
#              {'Name': 'entertainment', 'Score': 0.2151},
#              {'Name': 'politics', 'Score': 0.2005}],
#  'File': 'test.csv',
#  'Line': '132'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2135},
#              {'Name': 'business', 'Score': 0.2113},
#              {'Name': 'politics', 'Score': 0.2076}],
#  'File': 'test.csv',
#  'Line': '133'}
# {'Classes': [{'Name': 'business', 'Score': 0.2146},
#              {'Name': 'entertainment', 'Score': 0.2123},
#              {'Name': 'politics', 'Score': 0.2034}],
#  'File': 'test.csv',
#  'Line': '134'}
# {'Classes': [{'Name': 'business', 'Score': 0.2165},
#              {'Name': 'entertainment', 'Score': 0.2121},
#              {'Name': 'politics', 'Score': 0.2014}],
#  'File': 'test.csv',
#  'Line': '135'}
# {'Classes': [{'Name': 'business', 'Score': 0.2126},
#              {'Name': 'entertainment', 'Score': 0.2111},
#              {'Name': 'politics', 'Score': 0.2061}],
#  'File': 'test.csv',
#  'Line': '136'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2145},
#              {'Name': 'business', 'Score': 0.213},
#              {'Name': 'politics', 'Score': 0.2031}],
#  'File': 'test.csv',
#  'Line': '137'}
# {'Classes': [{'Name': 'business', 'Score': 0.2152},
#              {'Name': 'entertainment', 'Score': 0.2145},
#              {'Name': 'politics', 'Score': 0.2017}],
#  'File': 'test.csv',
#  'Line': '138'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.213},
#              {'Name': 'business', 'Score': 0.2115},
#              {'Name': 'politics', 'Score': 0.203}],
#  'File': 'test.csv',
#  'Line': '139'}
# {'Classes': [{'Name': 'business', 'Score': 0.2128},
#              {'Name': 'entertainment', 'Score': 0.2089},
#              {'Name': 'politics', 'Score': 0.2086}],
#  'File': 'test.csv',
#  'Line': '140'}
# {'Classes': [{'Name': 'business', 'Score': 0.2165},
#              {'Name': 'entertainment', 'Score': 0.2096},
#              {'Name': 'politics', 'Score': 0.2041}],
#  'File': 'test.csv',
#  'Line': '141'}
# {'Classes': [{'Name': 'business', 'Score': 0.2154},
#              {'Name': 'entertainment', 'Score': 0.2125},
#              {'Name': 'politics', 'Score': 0.2025}],
#  'File': 'test.csv',
#  'Line': '142'}
# {'Classes': [{'Name': 'business', 'Score': 0.2147},
#              {'Name': 'entertainment', 'Score': 0.2126},
#              {'Name': 'politics', 'Score': 0.2028}],
#  'File': 'test.csv',
#  'Line': '143'}
# {'Classes': [{'Name': 'business', 'Score': 0.2144},
#              {'Name': 'entertainment', 'Score': 0.2123},
#              {'Name': 'politics', 'Score': 0.2037}],
#  'File': 'test.csv',
#  'Line': '144'}
# {'Classes': [{'Name': 'business', 'Score': 0.2147},
#              {'Name': 'entertainment', 'Score': 0.2136},
#              {'Name': 'politics', 'Score': 0.2021}],
#  'File': 'test.csv',
#  'Line': '145'}
# {'Classes': [{'Name': 'business', 'Score': 0.2156},
#              {'Name': 'entertainment', 'Score': 0.2149},
#              {'Name': 'politics', 'Score': 0.2019}],
#  'File': 'test.csv',
#  'Line': '146'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2152},
#              {'Name': 'business', 'Score': 0.2147},
#              {'Name': 'politics', 'Score': 0.2012}],
#  'File': 'test.csv',
#  'Line': '147'}
# {'Classes': [{'Name': 'business', 'Score': 0.2132},
#              {'Name': 'entertainment', 'Score': 0.2117},
#              {'Name': 'politics', 'Score': 0.205}],
#  'File': 'test.csv',
#  'Line': '148'}
# {'Classes': [{'Name': 'business', 'Score': 0.2129},
#              {'Name': 'entertainment', 'Score': 0.2122},
#              {'Name': 'politics', 'Score': 0.2045}],
#  'File': 'test.csv',
#  'Line': '149'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2145},
#              {'Name': 'business', 'Score': 0.2145},
#              {'Name': 'politics', 'Score': 0.2008}],
#  'File': 'test.csv',
#  'Line': '150'}
# {'Classes': [{'Name': 'business', 'Score': 0.2145},
#              {'Name': 'entertainment', 'Score': 0.2091},
#              {'Name': 'politics', 'Score': 0.208}],
#  'File': 'test.csv',
#  'Line': '151'}
# {'Classes': [{'Name': 'business', 'Score': 0.214},
#              {'Name': 'entertainment', 'Score': 0.2107},
#              {'Name': 'politics', 'Score': 0.2065}],
#  'File': 'test.csv',
#  'Line': '152'}
# {'Classes': [{'Name': 'business', 'Score': 0.2138},
#              {'Name': 'entertainment', 'Score': 0.2114},
#              {'Name': 'politics', 'Score': 0.2057}],
#  'File': 'test.csv',
#  'Line': '153'}
# {'Classes': [{'Name': 'business', 'Score': 0.2159},
#              {'Name': 'entertainment', 'Score': 0.2098},
#              {'Name': 'politics', 'Score': 0.2054}],
#  'File': 'test.csv',
#  'Line': '154'}
# {'Classes': [{'Name': 'business', 'Score': 0.2138},
#              {'Name': 'entertainment', 'Score': 0.2114},
#              {'Name': 'politics', 'Score': 0.2057}],
#  'File': 'test.csv',
#  'Line': '155'}
# {'Classes': [{'Name': 'business', 'Score': 0.2159},
#              {'Name': 'entertainment', 'Score': 0.2123},
#              {'Name': 'politics', 'Score': 0.2048}],
#  'File': 'test.csv',
#  'Line': '156'}
# {'Classes': [{'Name': 'business', 'Score': 0.218},
#              {'Name': 'entertainment', 'Score': 0.2139},
#              {'Name': 'politics', 'Score': 0.1987}],
#  'File': 'test.csv',
#  'Line': '157'}
# {'Classes': [{'Name': 'business', 'Score': 0.2154},
#              {'Name': 'entertainment', 'Score': 0.2131},
#              {'Name': 'politics', 'Score': 0.2031}],
#  'File': 'test.csv',
#  'Line': '158'}
# {'Classes': [{'Name': 'business', 'Score': 0.2134},
#              {'Name': 'entertainment', 'Score': 0.2111},
#              {'Name': 'politics', 'Score': 0.2073}],
#  'File': 'test.csv',
#  'Line': '159'}
# {'Classes': [{'Name': 'business', 'Score': 0.2134},
#              {'Name': 'entertainment', 'Score': 0.2121},
#              {'Name': 'politics', 'Score': 0.2033}],
#  'File': 'test.csv',
#  'Line': '160'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2151},
#              {'Name': 'business', 'Score': 0.2149},
#              {'Name': 'politics', 'Score': 0.2003}],
#  'File': 'test.csv',
#  'Line': '161'}
# {'Classes': [{'Name': 'business', 'Score': 0.2128},
#              {'Name': 'entertainment', 'Score': 0.2103},
#              {'Name': 'politics', 'Score': 0.2064}],
#  'File': 'test.csv',
#  'Line': '162'}
# {'Classes': [{'Name': 'business', 'Score': 0.2133},
#              {'Name': 'entertainment', 'Score': 0.2101},
#              {'Name': 'politics', 'Score': 0.208}],
#  'File': 'test.csv',
#  'Line': '163'}
# {'Classes': [{'Name': 'business', 'Score': 0.2156},
#              {'Name': 'entertainment', 'Score': 0.2112},
#              {'Name': 'politics', 'Score': 0.2034}],
#  'File': 'test.csv',
#  'Line': '164'}
# {'Classes': [{'Name': 'business', 'Score': 0.2163},
#              {'Name': 'entertainment', 'Score': 0.2153},
#              {'Name': 'politics', 'Score': 0.2008}],
#  'File': 'test.csv',
#  'Line': '165'}
# {'Classes': [{'Name': 'business', 'Score': 0.2139},
#              {'Name': 'entertainment', 'Score': 0.213},
#              {'Name': 'politics', 'Score': 0.2027}],
#  'File': 'test.csv',
#  'Line': '166'}
# {'Classes': [{'Name': 'business', 'Score': 0.2161},
#              {'Name': 'entertainment', 'Score': 0.2127},
#              {'Name': 'politics', 'Score': 0.2013}],
#  'File': 'test.csv',
#  'Line': '167'}
# {'Classes': [{'Name': 'business', 'Score': 0.2135},
#              {'Name': 'entertainment', 'Score': 0.2124},
#              {'Name': 'politics', 'Score': 0.2068}],
#  'File': 'test.csv',
#  'Line': '168'}
# {'Classes': [{'Name': 'business', 'Score': 0.2159},
#              {'Name': 'entertainment', 'Score': 0.2149},
#              {'Name': 'politics', 'Score': 0.2009}],
#  'File': 'test.csv',
#  'Line': '169'}
# {'Classes': [{'Name': 'business', 'Score': 0.2144},
#              {'Name': 'entertainment', 'Score': 0.2133},
#              {'Name': 'sport', 'Score': 0.2016}],
#  'File': 'test.csv',
#  'Line': '170'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2144},
#              {'Name': 'business', 'Score': 0.2136},
#              {'Name': 'politics', 'Score': 0.2026}],
#  'File': 'test.csv',
#  'Line': '171'}
# {'Classes': [{'Name': 'business', 'Score': 0.2126},
#              {'Name': 'politics', 'Score': 0.21},
#              {'Name': 'entertainment', 'Score': 0.2087}],
#  'File': 'test.csv',
#  'Line': '172'}
# {'Classes': [{'Name': 'business', 'Score': 0.215},
#              {'Name': 'entertainment', 'Score': 0.2142},
#              {'Name': 'politics', 'Score': 0.2002}],
#  'File': 'test.csv',
#  'Line': '173'}
# {'Classes': [{'Name': 'business', 'Score': 0.2123},
#              {'Name': 'entertainment', 'Score': 0.2115},
#              {'Name': 'politics', 'Score': 0.2061}],
#  'File': 'test.csv',
#  'Line': '174'}
# {'Classes': [{'Name': 'business', 'Score': 0.2123},
#              {'Name': 'entertainment', 'Score': 0.2115},
#              {'Name': 'politics', 'Score': 0.2061}],
#  'File': 'test.csv',
#  'Line': '175'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2147},
#              {'Name': 'business', 'Score': 0.2138},
#              {'Name': 'politics', 'Score': 0.203}],
#  'File': 'test.csv',
#  'Line': '176'}
# {'Classes': [{'Name': 'business', 'Score': 0.2162},
#              {'Name': 'entertainment', 'Score': 0.2127},
#              {'Name': 'politics', 'Score': 0.201}],
#  'File': 'test.csv',
#  'Line': '177'}
# {'Classes': [{'Name': 'business', 'Score': 0.2135},
#              {'Name': 'entertainment', 'Score': 0.2124},
#              {'Name': 'politics', 'Score': 0.2068}],
#  'File': 'test.csv',
#  'Line': '178'}
# {'Classes': [{'Name': 'business', 'Score': 0.2139},
#              {'Name': 'entertainment', 'Score': 0.2126},
#              {'Name': 'politics', 'Score': 0.2032}],
#  'File': 'test.csv',
#  'Line': '179'}
# {'Classes': [{'Name': 'business', 'Score': 0.2151},
#              {'Name': 'entertainment', 'Score': 0.2116},
#              {'Name': 'politics', 'Score': 0.2048}],
#  'File': 'test.csv',
#  'Line': '180'}
# {'Classes': [{'Name': 'business', 'Score': 0.2149},
#              {'Name': 'entertainment', 'Score': 0.2096},
#              {'Name': 'politics', 'Score': 0.2063}],
#  'File': 'test.csv',
#  'Line': '181'}
# {'Classes': [{'Name': 'business', 'Score': 0.2143},
#              {'Name': 'entertainment', 'Score': 0.2099},
#              {'Name': 'politics', 'Score': 0.2062}],
#  'File': 'test.csv',
#  'Line': '182'}
# {'Classes': [{'Name': 'business', 'Score': 0.2153},
#              {'Name': 'entertainment', 'Score': 0.213},
#              {'Name': 'politics', 'Score': 0.2029}],
#  'File': 'test.csv',
#  'Line': '183'}
# {'Classes': [{'Name': 'business', 'Score': 0.2136},
#              {'Name': 'entertainment', 'Score': 0.212},
#              {'Name': 'politics', 'Score': 0.2051}],
#  'File': 'test.csv',
#  'Line': '184'}
# {'Classes': [{'Name': 'business', 'Score': 0.2153},
#              {'Name': 'entertainment', 'Score': 0.2118},
#              {'Name': 'politics', 'Score': 0.2007}],
#  'File': 'test.csv',
#  'Line': '185'}
# {'Classes': [{'Name': 'business', 'Score': 0.2155},
#              {'Name': 'entertainment', 'Score': 0.2145},
#              {'Name': 'politics', 'Score': 0.2016}],
#  'File': 'test.csv',
#  'Line': '186'}
# {'Classes': [{'Name': 'business', 'Score': 0.2134},
#              {'Name': 'entertainment', 'Score': 0.2102},
#              {'Name': 'politics', 'Score': 0.207}],
#  'File': 'test.csv',
#  'Line': '187'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2142},
#              {'Name': 'business', 'Score': 0.2116},
#              {'Name': 'politics', 'Score': 0.206}],
#  'File': 'test.csv',
#  'Line': '188'}
# {'Classes': [{'Name': 'business', 'Score': 0.216},
#              {'Name': 'entertainment', 'Score': 0.2147},
#              {'Name': 'politics', 'Score': 0.2005}],
#  'File': 'test.csv',
#  'Line': '189'}
# {'Classes': [{'Name': 'business', 'Score': 0.2113},
#              {'Name': 'entertainment', 'Score': 0.2097},
#              {'Name': 'politics', 'Score': 0.2078}],
#  'File': 'test.csv',
#  'Line': '190'}
# {'Classes': [{'Name': 'business', 'Score': 0.2139},
#              {'Name': 'entertainment', 'Score': 0.213},
#              {'Name': 'politics', 'Score': 0.2027}],
#  'File': 'test.csv',
#  'Line': '191'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2144},
#              {'Name': 'business', 'Score': 0.2139},
#              {'Name': 'politics', 'Score': 0.2037}],
#  'File': 'test.csv',
#  'Line': '192'}
# {'Classes': [{'Name': 'business', 'Score': 0.2161},
#              {'Name': 'entertainment', 'Score': 0.2127},
#              {'Name': 'politics', 'Score': 0.2013}],
#  'File': 'test.csv',
#  'Line': '193'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2139},
#              {'Name': 'business', 'Score': 0.2137},
#              {'Name': 'politics', 'Score': 0.2018}],
#  'File': 'test.csv',
#  'Line': '194'}
# {'Classes': [{'Name': 'business', 'Score': 0.2137},
#              {'Name': 'entertainment', 'Score': 0.2127},
#              {'Name': 'politics', 'Score': 0.2043}],
#  'File': 'test.csv',
#  'Line': '195'}
# {'Classes': [{'Name': 'business', 'Score': 0.2165},
#              {'Name': 'entertainment', 'Score': 0.2121},
#              {'Name': 'politics', 'Score': 0.2014}],
#  'File': 'test.csv',
#  'Line': '196'}
# {'Classes': [{'Name': 'business', 'Score': 0.2139},
#              {'Name': 'entertainment', 'Score': 0.2138},
#              {'Name': 'politics', 'Score': 0.2031}],
#  'File': 'test.csv',
#  'Line': '197'}
# {'Classes': [{'Name': 'business', 'Score': 0.2157},
#              {'Name': 'entertainment', 'Score': 0.2128},
#              {'Name': 'politics', 'Score': 0.203}],
#  'File': 'test.csv',
#  'Line': '198'}
# {'Classes': [{'Name': 'business', 'Score': 0.2151},
#              {'Name': 'entertainment', 'Score': 0.2148},
#              {'Name': 'politics', 'Score': 0.2012}],
#  'File': 'test.csv',
#  'Line': '199'}
# {'Classes': [{'Name': 'business', 'Score': 0.2161},
#              {'Name': 'entertainment', 'Score': 0.2131},
#              {'Name': 'politics', 'Score': 0.2032}],
#  'File': 'test.csv',
#  'Line': '200'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2164},
#              {'Name': 'business', 'Score': 0.2163},
#              {'Name': 'politics', 'Score': 0.2005}],
#  'File': 'test.csv',
#  'Line': '201'}
# {'Classes': [{'Name': 'business', 'Score': 0.2141},
#              {'Name': 'entertainment', 'Score': 0.2092},
#              {'Name': 'politics', 'Score': 0.2053}],
#  'File': 'test.csv',
#  'Line': '202'}
# {'Classes': [{'Name': 'business', 'Score': 0.2153},
#              {'Name': 'entertainment', 'Score': 0.213},
#              {'Name': 'politics', 'Score': 0.2029}],
#  'File': 'test.csv',
#  'Line': '203'}
# {'Classes': [{'Name': 'business', 'Score': 0.2166},
#              {'Name': 'entertainment', 'Score': 0.213},
#              {'Name': 'politics', 'Score': 0.2026}],
#  'File': 'test.csv',
#  'Line': '204'}
# {'Classes': [{'Name': 'business', 'Score': 0.2162},
#              {'Name': 'entertainment', 'Score': 0.2121},
#              {'Name': 'politics', 'Score': 0.2039}],
#  'File': 'test.csv',
#  'Line': '205'}
# {'Classes': [{'Name': 'business', 'Score': 0.2153},
#              {'Name': 'entertainment', 'Score': 0.2118},
#              {'Name': 'politics', 'Score': 0.2007}],
#  'File': 'test.csv',
#  'Line': '206'}
# {'Classes': [{'Name': 'business', 'Score': 0.2172},
#              {'Name': 'entertainment', 'Score': 0.2149},
#              {'Name': 'politics', 'Score': 0.1988}],
#  'File': 'test.csv',
#  'Line': '207'}
# {'Classes': [{'Name': 'business', 'Score': 0.2124},
#              {'Name': 'entertainment', 'Score': 0.2114},
#              {'Name': 'politics', 'Score': 0.2049}],
#  'File': 'test.csv',
#  'Line': '208'}
# {'Classes': [{'Name': 'business', 'Score': 0.2155},
#              {'Name': 'entertainment', 'Score': 0.2137},
#              {'Name': 'politics', 'Score': 0.2032}],
#  'File': 'test.csv',
#  'Line': '209'}
# {'Classes': [{'Name': 'business', 'Score': 0.2165},
#              {'Name': 'entertainment', 'Score': 0.2121},
#              {'Name': 'politics', 'Score': 0.2014}],
#  'File': 'test.csv',
#  'Line': '210'}
# {'Classes': [{'Name': 'business', 'Score': 0.2168},
#              {'Name': 'entertainment', 'Score': 0.2139},
#              {'Name': 'politics', 'Score': 0.1998}],
#  'File': 'test.csv',
#  'Line': '211'}
# {'Classes': [{'Name': 'business', 'Score': 0.2151},
#              {'Name': 'entertainment', 'Score': 0.211},
#              {'Name': 'politics', 'Score': 0.2029}],
#  'File': 'test.csv',
#  'Line': '212'}
# {'Classes': [{'Name': 'business', 'Score': 0.2157},
#              {'Name': 'entertainment', 'Score': 0.2115},
#              {'Name': 'politics', 'Score': 0.2025}],
#  'File': 'test.csv',
#  'Line': '213'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2128},
#              {'Name': 'business', 'Score': 0.2124},
#              {'Name': 'politics', 'Score': 0.2049}],
#  'File': 'test.csv',
#  'Line': '214'}
# {'Classes': [{'Name': 'business', 'Score': 0.2143},
#              {'Name': 'entertainment', 'Score': 0.2113},
#              {'Name': 'politics', 'Score': 0.2046}],
#  'File': 'test.csv',
#  'Line': '215'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2151},
#              {'Name': 'business', 'Score': 0.2147},
#              {'Name': 'politics', 'Score': 0.2016}],
#  'File': 'test.csv',
#  'Line': '216'}
# {'Classes': [{'Name': 'business', 'Score': 0.2164},
#              {'Name': 'entertainment', 'Score': 0.2163},
#              {'Name': 'politics', 'Score': 0.2001}],
#  'File': 'test.csv',
#  'Line': '217'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.216},
#              {'Name': 'business', 'Score': 0.2132},
#              {'Name': 'politics', 'Score': 0.2004}],
#  'File': 'test.csv',
#  'Line': '218'}
# {'Classes': [{'Name': 'business', 'Score': 0.2133},
#              {'Name': 'entertainment', 'Score': 0.2116},
#              {'Name': 'politics', 'Score': 0.2051}],
#  'File': 'test.csv',
#  'Line': '219'}
# {'Classes': [{'Name': 'business', 'Score': 0.2135},
#              {'Name': 'entertainment', 'Score': 0.2124},
#              {'Name': 'politics', 'Score': 0.2068}],
#  'File': 'test.csv',
#  'Line': '220'}
# {'Classes': [{'Name': 'business', 'Score': 0.2169},
#              {'Name': 'entertainment', 'Score': 0.2113},
#              {'Name': 'politics', 'Score': 0.2031}],
#  'File': 'test.csv',
#  'Line': '221'}
# {'Classes': [{'Name': 'business', 'Score': 0.2127},
#              {'Name': 'entertainment', 'Score': 0.2114},
#              {'Name': 'politics', 'Score': 0.2058}],
#  'File': 'test.csv',
#  'Line': '222'}
# {'Classes': [{'Name': 'business', 'Score': 0.216},
#              {'Name': 'entertainment', 'Score': 0.215},
#              {'Name': 'sport', 'Score': 0.1995}],
#  'File': 'test.csv',
#  'Line': '223'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2114},
#              {'Name': 'business', 'Score': 0.2111},
#              {'Name': 'politics', 'Score': 0.2074}],
#  'File': 'test.csv',
#  'Line': '224'}
# {'Classes': [{'Name': 'business', 'Score': 0.217},
#              {'Name': 'entertainment', 'Score': 0.2105},
#              {'Name': 'politics', 'Score': 0.204}],
#  'File': 'test.csv',
#  'Line': '225'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2155},
#              {'Name': 'business', 'Score': 0.2148},
#              {'Name': 'politics', 'Score': 0.2012}],
#  'File': 'test.csv',
#  'Line': '226'}
# {'Classes': [{'Name': 'business', 'Score': 0.2139},
#              {'Name': 'entertainment', 'Score': 0.2126},
#              {'Name': 'politics', 'Score': 0.2032}],
#  'File': 'test.csv',
#  'Line': '227'}
# {'Classes': [{'Name': 'business', 'Score': 0.2149},
#              {'Name': 'entertainment', 'Score': 0.2134},
#              {'Name': 'politics', 'Score': 0.2022}],
#  'File': 'test.csv',
#  'Line': '228'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2155},
#              {'Name': 'business', 'Score': 0.2128},
#              {'Name': 'politics', 'Score': 0.2017}],
#  'File': 'test.csv',
#  'Line': '229'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2124},
#              {'Name': 'business', 'Score': 0.2117},
#              {'Name': 'politics', 'Score': 0.2059}],
#  'File': 'test.csv',
#  'Line': '230'}
# {'Classes': [{'Name': 'business', 'Score': 0.217},
#              {'Name': 'entertainment', 'Score': 0.2105},
#              {'Name': 'politics', 'Score': 0.204}],
#  'File': 'test.csv',
#  'Line': '231'}
# {'Classes': [{'Name': 'business', 'Score': 0.2156},
#              {'Name': 'entertainment', 'Score': 0.2149},
#              {'Name': 'politics', 'Score': 0.2019}],
#  'File': 'test.csv',
#  'Line': '232'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2159},
#              {'Name': 'business', 'Score': 0.2153},
#              {'Name': 'politics', 'Score': 0.2001}],
#  'File': 'test.csv',
#  'Line': '233'}
# {'Classes': [{'Name': 'business', 'Score': 0.2118},
#              {'Name': 'entertainment', 'Score': 0.2102},
#              {'Name': 'politics', 'Score': 0.2051}],
#  'File': 'test.csv',
#  'Line': '234'}
# {'Classes': [{'Name': 'business', 'Score': 0.2139},
#              {'Name': 'entertainment', 'Score': 0.2108},
#              {'Name': 'politics', 'Score': 0.204}],
#  'File': 'test.csv',
#  'Line': '235'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2133},
#              {'Name': 'business', 'Score': 0.213},
#              {'Name': 'politics', 'Score': 0.2031}],
#  'File': 'test.csv',
#  'Line': '236'}
# {'Classes': [{'Name': 'business', 'Score': 0.215},
#              {'Name': 'entertainment', 'Score': 0.2118},
#              {'Name': 'politics', 'Score': 0.2047}],
#  'File': 'test.csv',
#  'Line': '237'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.215},
#              {'Name': 'business', 'Score': 0.2133},
#              {'Name': 'politics', 'Score': 0.2023}],
#  'File': 'test.csv',
#  'Line': '238'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2138},
#              {'Name': 'business', 'Score': 0.2118},
#              {'Name': 'politics', 'Score': 0.2051}],
#  'File': 'test.csv',
#  'Line': '239'}
# {'Classes': [{'Name': 'business', 'Score': 0.219},
#              {'Name': 'entertainment', 'Score': 0.2137},
#              {'Name': 'politics', 'Score': 0.1991}],
#  'File': 'test.csv',
#  'Line': '240'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2123},
#              {'Name': 'business', 'Score': 0.2103},
#              {'Name': 'politics', 'Score': 0.2053}],
#  'File': 'test.csv',
#  'Line': '241'}
# ...
#              {'Name': 'politics', 'Score': 0.2052}],
#  'File': 'test.csv',
#  'Line': '369'}
# {'Classes': [{'Name': 'business', 'Score': 0.2141},
#              {'Name': 'entertainment', 'Score': 0.2117},
#              {'Name': 'politics', 'Score': 0.2058}],
#  'File': 'test.csv',
#  'Line': '370'}
# {'Classes': [{'Name': 'business', 'Score': 0.2153},
#              {'Name': 'entertainment', 'Score': 0.2098},
#              {'Name': 'politics', 'Score': 0.2075}],
#  'File': 'test.csv',
#  'Line': '371'}
# {'Classes': [{'Name': 'business', 'Score': 0.2174},
#              {'Name': 'entertainment', 'Score': 0.2139},
#              {'Name': 'politics', 'Score': 0.2004}],
#  'File': 'test.csv',
#  'Line': '372'}
# {'Classes': [{'Name': 'business', 'Score': 0.2163},
#              {'Name': 'entertainment', 'Score': 0.2106},
#              {'Name': 'politics', 'Score': 0.2044}],
#  'File': 'test.csv',
#  'Line': '373'}
# {'Classes': [{'Name': 'business', 'Score': 0.2141},
#              {'Name': 'entertainment', 'Score': 0.2136},
#              {'Name': 'politics', 'Score': 0.2023}],
#  'File': 'test.csv',
#  'Line': '374'}
# {'Classes': [{'Name': 'business', 'Score': 0.2125},
#              {'Name': 'entertainment', 'Score': 0.2087},
#              {'Name': 'politics', 'Score': 0.208}],
#  'File': 'test.csv',
#  'Line': '375'}
# {'Classes': [{'Name': 'business', 'Score': 0.2148},
#              {'Name': 'entertainment', 'Score': 0.2127},
#              {'Name': 'politics', 'Score': 0.2017}],
#  'File': 'test.csv',
#  'Line': '376'}
# {'Classes': [{'Name': 'business', 'Score': 0.2158},
#              {'Name': 'entertainment', 'Score': 0.2111},
#              {'Name': 'politics', 'Score': 0.2009}],
#  'File': 'test.csv',
#  'Line': '377'}
# {'Classes': [{'Name': 'business', 'Score': 0.2137},
#              {'Name': 'entertainment', 'Score': 0.2127},
#              {'Name': 'politics', 'Score': 0.2043}],
#  'File': 'test.csv',
#  'Line': '378'}
# {'Classes': [{'Name': 'business', 'Score': 0.2153},
#              {'Name': 'entertainment', 'Score': 0.2122},
#              {'Name': 'politics', 'Score': 0.2017}],
#  'File': 'test.csv',
#  'Line': '379'}
# {'Classes': [{'Name': 'business', 'Score': 0.2158},
#              {'Name': 'entertainment', 'Score': 0.2125},
#              {'Name': 'politics', 'Score': 0.2023}],
#  'File': 'test.csv',
#  'Line': '380'}
# {'Classes': [{'Name': 'business', 'Score': 0.2174},
#              {'Name': 'entertainment', 'Score': 0.2123},
#              {'Name': 'politics', 'Score': 0.2027}],
#  'File': 'test.csv',
#  'Line': '381'}
# {'Classes': [{'Name': 'business', 'Score': 0.216},
#              {'Name': 'entertainment', 'Score': 0.2147},
#              {'Name': 'politics', 'Score': 0.2005}],
#  'File': 'test.csv',
#  'Line': '382'}
# {'Classes': [{'Name': 'business', 'Score': 0.2159},
#              {'Name': 'entertainment', 'Score': 0.2098},
#              {'Name': 'politics', 'Score': 0.2054}],
#  'File': 'test.csv',
#  'Line': '383'}
# {'Classes': [{'Name': 'business', 'Score': 0.2154},
#              {'Name': 'entertainment', 'Score': 0.2127},
#              {'Name': 'politics', 'Score': 0.2044}],
#  'File': 'test.csv',
#  'Line': '384'}
# {'Classes': [{'Name': 'business', 'Score': 0.2133},
#              {'Name': 'entertainment', 'Score': 0.2116},
#              {'Name': 'politics', 'Score': 0.2051}],
#  'File': 'test.csv',
#  'Line': '385'}
# {'Classes': [{'Name': 'business', 'Score': 0.2138},
#              {'Name': 'entertainment', 'Score': 0.2089},
#              {'Name': 'politics', 'Score': 0.2081}],
#  'File': 'test.csv',
#  'Line': '386'}
# {'Classes': [{'Name': 'business', 'Score': 0.2153},
#              {'Name': 'entertainment', 'Score': 0.2118},
#              {'Name': 'politics', 'Score': 0.2007}],
#  'File': 'test.csv',
#  'Line': '387'}
# {'Classes': [{'Name': 'business', 'Score': 0.215},
#              {'Name': 'entertainment', 'Score': 0.2134},
#              {'Name': 'politics', 'Score': 0.2038}],
#  'File': 'test.csv',
#  'Line': '388'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2151},
#              {'Name': 'business', 'Score': 0.2149},
#              {'Name': 'politics', 'Score': 0.2003}],
#  'File': 'test.csv',
#  'Line': '389'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2147},
#              {'Name': 'business', 'Score': 0.2138},
#              {'Name': 'politics', 'Score': 0.203}],
#  'File': 'test.csv',
#  'Line': '390'}
# {'Classes': [{'Name': 'business', 'Score': 0.2156},
#              {'Name': 'entertainment', 'Score': 0.2112},
#              {'Name': 'politics', 'Score': 0.2034}],
#  'File': 'test.csv',
#  'Line': '391'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2138},
#              {'Name': 'business', 'Score': 0.2126},
#              {'Name': 'politics', 'Score': 0.2031}],
#  'File': 'test.csv',
#  'Line': '392'}
# {'Classes': [{'Name': 'business', 'Score': 0.216},
#              {'Name': 'entertainment', 'Score': 0.215},
#              {'Name': 'sport', 'Score': 0.1995}],
#  'File': 'test.csv',
#  'Line': '393'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2161},
#              {'Name': 'business', 'Score': 0.2118},
#              {'Name': 'sport', 'Score': 0.2002}],
#  'File': 'test.csv',
#  'Line': '394'}
# {'Classes': [{'Name': 'business', 'Score': 0.2147},
#              {'Name': 'entertainment', 'Score': 0.2124},
#              {'Name': 'politics', 'Score': 0.2018}],
#  'File': 'test.csv',
#  'Line': '395'}
# {'Classes': [{'Name': 'business', 'Score': 0.2156},
#              {'Name': 'entertainment', 'Score': 0.2139},
#              {'Name': 'politics', 'Score': 0.2009}],
#  'File': 'test.csv',
#  'Line': '396'}
# {'Classes': [{'Name': 'business', 'Score': 0.2141},
#              {'Name': 'entertainment', 'Score': 0.211},
#              {'Name': 'politics', 'Score': 0.2059}],
#  'File': 'test.csv',
#  'Line': '397'}
# {'Classes': [{'Name': 'business', 'Score': 0.2151},
#              {'Name': 'entertainment', 'Score': 0.2127},
#              {'Name': 'politics', 'Score': 0.203}],
#  'File': 'test.csv',
#  'Line': '398'}
# {'Classes': [{'Name': 'business', 'Score': 0.2128},
#              {'Name': 'entertainment', 'Score': 0.2103},
#              {'Name': 'politics', 'Score': 0.2064}],
#  'File': 'test.csv',
#  'Line': '399'}
# {'Classes': [{'Name': 'business', 'Score': 0.2188},
#              {'Name': 'entertainment', 'Score': 0.2151},
#              {'Name': 'politics', 'Score': 0.1983}],
#  'File': 'test.csv',
#  'Line': '400'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2164},
#              {'Name': 'business', 'Score': 0.2163},
#              {'Name': 'politics', 'Score': 0.2005}],
#  'File': 'test.csv',
#  'Line': '401'}
# {'Classes': [{'Name': 'business', 'Score': 0.2141},
#              {'Name': 'entertainment', 'Score': 0.2136},
#              {'Name': 'politics', 'Score': 0.2023}],
#  'File': 'test.csv',
#  'Line': '402'}
# {'Classes': [{'Name': 'business', 'Score': 0.2166},
#              {'Name': 'entertainment', 'Score': 0.2148},
#              {'Name': 'politics', 'Score': 0.2027}],
#  'File': 'test.csv',
#  'Line': '403'}
# {'Classes': [{'Name': 'business', 'Score': 0.2153},
#              {'Name': 'entertainment', 'Score': 0.2122},
#              {'Name': 'politics', 'Score': 0.2017}],
#  'File': 'test.csv',
#  'Line': '404'}
# {'Classes': [{'Name': 'business', 'Score': 0.2154},
#              {'Name': 'entertainment', 'Score': 0.2127},
#              {'Name': 'politics', 'Score': 0.2044}],
#  'File': 'test.csv',
#  'Line': '405'}
# {'Classes': [{'Name': 'business', 'Score': 0.2164},
#              {'Name': 'entertainment', 'Score': 0.2145},
#              {'Name': 'politics', 'Score': 0.2007}],
#  'File': 'test.csv',
#  'Line': '406'}
# {'Classes': [{'Name': 'business', 'Score': 0.2163},
#              {'Name': 'entertainment', 'Score': 0.2127},
#              {'Name': 'politics', 'Score': 0.2025}],
#  'File': 'test.csv',
#  'Line': '407'}
# {'Classes': [{'Name': 'business', 'Score': 0.2149},
#              {'Name': 'entertainment', 'Score': 0.2137},
#              {'Name': 'politics', 'Score': 0.2009}],
#  'File': 'test.csv',
#  'Line': '408'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2144},
#              {'Name': 'business', 'Score': 0.2127},
#              {'Name': 'politics', 'Score': 0.2044}],
#  'File': 'test.csv',
#  'Line': '409'}
# {'Classes': [{'Name': 'business', 'Score': 0.2113},
#              {'Name': 'entertainment', 'Score': 0.2097},
#              {'Name': 'politics', 'Score': 0.2078}],
#  'File': 'test.csv',
#  'Line': '410'}
# {'Classes': [{'Name': 'business', 'Score': 0.2189},
#              {'Name': 'entertainment', 'Score': 0.2158},
#              {'Name': 'politics', 'Score': 0.198}],
#  'File': 'test.csv',
#  'Line': '411'}
# {'Classes': [{'Name': 'business', 'Score': 0.217},
#              {'Name': 'entertainment', 'Score': 0.2105},
#              {'Name': 'politics', 'Score': 0.204}],
#  'File': 'test.csv',
#  'Line': '412'}
# {'Classes': [{'Name': 'business', 'Score': 0.2143},
#              {'Name': 'entertainment', 'Score': 0.2099},
#              {'Name': 'politics', 'Score': 0.2062}],
#  'File': 'test.csv',
#  'Line': '413'}
# {'Classes': [{'Name': 'business', 'Score': 0.2151},
#              {'Name': 'entertainment', 'Score': 0.2127},
#              {'Name': 'politics', 'Score': 0.203}],
#  'File': 'test.csv',
#  'Line': '414'}
# {'Classes': [{'Name': 'business', 'Score': 0.2141},
#              {'Name': 'entertainment', 'Score': 0.2138},
#              {'Name': 'politics', 'Score': 0.2005}],
#  'File': 'test.csv',
#  'Line': '415'}
# {'Classes': [{'Name': 'business', 'Score': 0.2132},
#              {'Name': 'entertainment', 'Score': 0.211},
#              {'Name': 'politics', 'Score': 0.2052}],
#  'File': 'test.csv',
#  'Line': '416'}
# {'Classes': [{'Name': 'business', 'Score': 0.2134},
#              {'Name': 'entertainment', 'Score': 0.2102},
#              {'Name': 'politics', 'Score': 0.207}],
#  'File': 'test.csv',
#  'Line': '417'}
# {'Classes': [{'Name': 'business', 'Score': 0.2147},
#              {'Name': 'politics', 'Score': 0.2092},
#              {'Name': 'entertainment', 'Score': 0.2073}],
#  'File': 'test.csv',
#  'Line': '418'}
# {'Classes': [{'Name': 'business', 'Score': 0.2153},
#              {'Name': 'entertainment', 'Score': 0.2127},
#              {'Name': 'politics', 'Score': 0.2025}],
#  'File': 'test.csv',
#  'Line': '419'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2172},
#              {'Name': 'business', 'Score': 0.2164},
#              {'Name': 'sport', 'Score': 0.1989}],
#  'File': 'test.csv',
#  'Line': '420'}
# {'Classes': [{'Name': 'business', 'Score': 0.2134},
#              {'Name': 'entertainment', 'Score': 0.2102},
#              {'Name': 'politics', 'Score': 0.207}],
#  'File': 'test.csv',
#  'Line': '421'}
# {'Classes': [{'Name': 'business', 'Score': 0.2138},
#              {'Name': 'entertainment', 'Score': 0.2134},
#              {'Name': 'politics', 'Score': 0.2033}],
#  'File': 'test.csv',
#  'Line': '422'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.215},
#              {'Name': 'business', 'Score': 0.2148},
#              {'Name': 'politics', 'Score': 0.2016}],
#  'File': 'test.csv',
#  'Line': '423'}
# {'Classes': [{'Name': 'business', 'Score': 0.2148},
#              {'Name': 'entertainment', 'Score': 0.2113},
#              {'Name': 'politics', 'Score': 0.2057}],
#  'File': 'test.csv',
#  'Line': '424'}
# {'Classes': [{'Name': 'business', 'Score': 0.2125},
#              {'Name': 'entertainment', 'Score': 0.2087},
#              {'Name': 'politics', 'Score': 0.208}],
#  'File': 'test.csv',
#  'Line': '425'}
# {'Classes': [{'Name': 'business', 'Score': 0.2137},
#              {'Name': 'entertainment', 'Score': 0.2115},
#              {'Name': 'politics', 'Score': 0.2037}],
#  'File': 'test.csv',
#  'Line': '426'}
# {'Classes': [{'Name': 'business', 'Score': 0.216},
#              {'Name': 'entertainment', 'Score': 0.2135},
#              {'Name': 'politics', 'Score': 0.2027}],
#  'File': 'test.csv',
#  'Line': '427'}
# {'Classes': [{'Name': 'business', 'Score': 0.217},
#              {'Name': 'entertainment', 'Score': 0.2137},
#              {'Name': 'politics', 'Score': 0.2}],
#  'File': 'test.csv',
#  'Line': '428'}
# {'Classes': [{'Name': 'business', 'Score': 0.2138},
#              {'Name': 'entertainment', 'Score': 0.2118},
#              {'Name': 'politics', 'Score': 0.2048}],
#  'File': 'test.csv',
#  'Line': '429'}
# {'Classes': [{'Name': 'business', 'Score': 0.2166},
#              {'Name': 'entertainment', 'Score': 0.213},
#              {'Name': 'politics', 'Score': 0.2026}],
#  'File': 'test.csv',
#  'Line': '430'}
# {'Classes': [{'Name': 'business', 'Score': 0.2149},
#              {'Name': 'entertainment', 'Score': 0.2096},
#              {'Name': 'politics', 'Score': 0.2063}],
#  'File': 'test.csv',
#  'Line': '431'}
# {'Classes': [{'Name': 'business', 'Score': 0.2139},
#              {'Name': 'entertainment', 'Score': 0.2126},
#              {'Name': 'politics', 'Score': 0.2032}],
#  'File': 'test.csv',
#  'Line': '432'}
# {'Classes': [{'Name': 'business', 'Score': 0.2153},
#              {'Name': 'entertainment', 'Score': 0.213},
#              {'Name': 'politics', 'Score': 0.2029}],
#  'File': 'test.csv',
#  'Line': '433'}
# {'Classes': [{'Name': 'business', 'Score': 0.2147},
#              {'Name': 'politics', 'Score': 0.2092},
#              {'Name': 'entertainment', 'Score': 0.2073}],
#  'File': 'test.csv',
#  'Line': '434'}
# {'Classes': [{'Name': 'business', 'Score': 0.215},
#              {'Name': 'politics', 'Score': 0.2084},
#              {'Name': 'entertainment', 'Score': 0.2061}],
#  'File': 'test.csv',
#  'Line': '435'}
# {'Classes': [{'Name': 'business', 'Score': 0.2142},
#              {'Name': 'entertainment', 'Score': 0.2082},
#              {'Name': 'politics', 'Score': 0.2058}],
#  'File': 'test.csv',
#  'Line': '436'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2155},
#              {'Name': 'business', 'Score': 0.2128},
#              {'Name': 'politics', 'Score': 0.2017}],
#  'File': 'test.csv',
#  'Line': '437'}
# {'Classes': [{'Name': 'business', 'Score': 0.2154},
#              {'Name': 'entertainment', 'Score': 0.2133},
#              {'Name': 'politics', 'Score': 0.2027}],
#  'File': 'test.csv',
#  'Line': '438'}
# {'Classes': [{'Name': 'business', 'Score': 0.2161},
#              {'Name': 'entertainment', 'Score': 0.2122},
#              {'Name': 'politics', 'Score': 0.2041}],
#  'File': 'test.csv',
#  'Line': '439'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2155},
#              {'Name': 'business', 'Score': 0.2148},
#              {'Name': 'politics', 'Score': 0.2012}],
#  'File': 'test.csv',
#  'Line': '440'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2137},
#              {'Name': 'business', 'Score': 0.2133},
#              {'Name': 'politics', 'Score': 0.2042}],
#  'File': 'test.csv',
#  'Line': '441'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2151},
#              {'Name': 'business', 'Score': 0.2149},
#              {'Name': 'politics', 'Score': 0.2003}],
#  'File': 'test.csv',
#  'Line': '442'}
# {'Classes': [{'Name': 'business', 'Score': 0.2151},
#              {'Name': 'entertainment', 'Score': 0.2148},
#              {'Name': 'politics', 'Score': 0.2012}],
#  'File': 'test.csv',
#  'Line': '443'}
# {'Classes': [{'Name': 'business', 'Score': 0.2192},
#              {'Name': 'entertainment', 'Score': 0.2147},
#              {'Name': 'sport', 'Score': 0.1973}],
#  'File': 'test.csv',
#  'Line': '444'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2124},
#              {'Name': 'business', 'Score': 0.2117},
#              {'Name': 'politics', 'Score': 0.2059}],
#  'File': 'test.csv',
#  'Line': '445'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2124},
#              {'Name': 'business', 'Score': 0.2117},
#              {'Name': 'politics', 'Score': 0.2046}],
#  'File': 'test.csv',
#  'Line': '446'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2129},
#              {'Name': 'business', 'Score': 0.2118},
#              {'Name': 'politics', 'Score': 0.2045}],
#  'File': 'test.csv',
#  'Line': '447'}
# {'Classes': [{'Name': 'entertainment', 'Score': 0.2121},
#              {'Name': 'business', 'Score': 0.212},
#              {'Name': 'politics', 'Score': 0.2072}],
#  'File': 'test.csv',
#  'Line': '448'}
# {'Classes': [{'Name': 'business', 'Score': 0.2138},
#              {'Name': 'entertainment', 'Score': 0.2122},
#              {'Name': 'politics', 'Score': 0.2052}],
#  'File': 'test.csv',
#  'Line': '449'}

# %%
predictedLabels = []
for line in file:
    predictedLabels.append(json.loads(line)['Classes'][0]['Name'])

# %%
df_truth['pred'] = predictedLabels

# %%
print('Precision: ',precision_score(df_truth['pred'], df_truth['label'],average='weighted'))
# Out:
# Precision:  0.660888888888889
